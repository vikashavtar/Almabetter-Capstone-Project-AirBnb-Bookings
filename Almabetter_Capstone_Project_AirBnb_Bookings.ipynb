# %% [markdown]
# <a href="https://colab.research.google.com/github/vikashavtar/Almabetter-Capstone-Project-AirBnb-Bookings/blob/main/Almabetter_Capstone_Project_AirBnb_Bookings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Capstone Project on  Airbnb Bookings Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ##Airbnb stands for 'Air Bed and Breakfast', and it is an online service that lets property owners rent out their premises, houses, or places to travelers looking for a place to stay. The prices of Airbnb premises are comparatively cheaper than hotels. And it allows the owner to fix the price of premises for the traveler. These days' people are preferring Airbnb to stay instead of expensive and luxurious hotels. In this growing industry, there is a lot of competition among hosts, all hosts want to make their listings attractive, and it is difficult for some hosts to make their listings attractive. Using data science, we make this problem quite simple by collecting lots of data and analyzing it using python's libraries (i.e., pandas, numpy, seaborn, and matplotlib). This analysis helps us to attract customers and give them world-class service at their level, and so different types of factors like price, area, reviews, and services affect their choices. Here, we will analyze the data and try to make a correlation between different variables, and find the relation between top listings so that in the future a host can take business decisions using these insights gained after EDA.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vikashavtar/Almabetter-Capstone-Project-AirBnb-Bookings/blob/main/Almabetter_Capstone_Project_AirBnb_Bookings.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the given data, our first step is to identify
# all the variables and find out the relationship
# between them. Our first sub-problem is that
# first focus on its physical features and its
# facilities and find out the relationship
# between top listings with prices.
# We mainly focused on the listing's room
# type, the property type, price, host, location,
# and reviews.
#
# * id: all properties have a unique id by
# which we tried to find unique
# properties.
#
# * Host_id: all the hosts have a unique id
# by which we tried to find unique
# number of hosts, their maximum
# number of listings, most popular host
# and their charges.
#
# * Neighbourhood_group &
# neighborhood: by this, we tried to
# find out which neighborhood group
# has the maximum number of
# properties, which one is the most
# popular, which one is the most
# expensive place to live.
#
# * Room_type: In the given data, there
# are three types of rooms are available
# that is private, shared, and entire
# home and we tried to find out
# which types of rooms are the most
# popular and most expensive.
#
# * Number_of_reviews: by this, we tried
# to find out which property has the
# best service and which host provides
# the best service.
#
# * Availability_365: by this, we tried
#  to find the availability of the property

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Exploratory data analysis of NYC Airbnb Bookings Analysis by analyzing all the variables, we have to find the factor that will help the host to grow their Airbnb business

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(8, 6))

plt.rcParams.update({'figure.figsize':(8,6),'figure.dpi':100})

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#reading the dataset


df = pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('The number of rows in data is:',df.shape[0])
print('The number of columns in data is',len(list(df.columns)))
# Out:
# The number of rows in data is: 48895
# The number of columns in data is 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_rows_in_AIrbnb = df.duplicated().sum()
print('The number of duplicates in store data is:',duplicate_rows_in_AIrbnb)
# Out:
# The number of duplicates in store data is: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb has become one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts') behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services, and much more. This dataset has around 49,000 observations with 16 columns, and it is a mix of categorical and numeric values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(df.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  *  id: In our dataset, every premise has a unique id
#
# *  host_id: All the hosts have unique IDs by which they are working, and a host has multiple IDs.
#
# *  neighbourhood_group & neighborhood: Within our dataset, four neighborhood groups contain multiple numbers of the neighborhood in which Airbnb is working.
#
# *  room_type: in the given data, there are three types of rooms available that is private, shared, and the entire home.
#
# *  number_of_reviews: All the premises are reviewed and rated by users based on their living experiences.
#
# *  Availability_365: In this, it has been talked about the availability for how many days the premises remain available for booking throughout the year.
#
# * latitude & longitude: The location of each premise has been given here.
#
# * minimum_nights: It is given the minimum number of nights that people stay on this premises.
#
# * calculated_host_listings_count: It denotes how many hosts are registered in this particular premises.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
df.drop(['id','host_id'], axis=1, inplace=True) # Remove irrelavant features from the dataset.

# %%
## Hence, the last_review and reviews_per_month has lots of null values so, remove these two columns
df.drop(['last_review','reviews_per_month'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                name    host_name  \
# 0                Clean & quiet apt home by the park         John
# 1                             Skylit Midtown Castle     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !    Elisabeth
# 3                   Cozy Entire Floor of Brownstone  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
df['name'].value_counts()
#an interesting observation, looks like few listings have no particular host name as below observation!
#also few listings/property with same names has different hosts in different areas/neighbourhoods of a neighbourhood_group
# Out:
# name
# Hillside Hotel                                        18
# Home away from home                                   17
# New york Multi-unit building                          16
# Brooklyn Apartment                                    12
# Loft Suite @ The Box House Hotel                      11
#                                                       ..
# Large 1BR Apt. in Williamsburg                         1
# Feel at Home                                           1
# Spacious Modern Alcove Studio in a Luxury Building     1
# Artist's Room in Large Apartment                       1
# Trendy duplex in the very heart of Hell's Kitchen      1
# Name: count, Length: 47905, dtype: int64

# %%
df['host_name'].nunique()
#it's looklike that same host are listed with diffrent diffrent id
# Out:
# 11452

# %%
# Find the calculated host listings count
df1=df.groupby(['host_name'])['calculated_host_listings_count'].max().reset_index().sort_values(by='calculated_host_listings_count', ascending=False).head()
df1
# Out:
#          host_name  calculated_host_listings_count
# 9781  Sonder (NYC)                             327
# 1356    Blueground                             232
# 5336          Kara                             121
# 5471        Kazuya                             103
# 9780        Sonder                              96

# %%
# Find the number of listing areawise (neighbourhood) using groupby operation
df2 = df.groupby(['neighbourhood_group'])['calculated_host_listings_count'].sum().reset_index().sort_values(by='calculated_host_listings_count', ascending=False)
df2
# Out:
#   neighbourhood_group  calculated_host_listings_count
# 2           Manhattan                          277073
# 1            Brooklyn                           45925
# 3              Queens                           23005
# 0               Bronx                            2437
# 4       Staten Island                             865

# %%
dfv =df.groupby(['neighbourhood_group'])['number_of_reviews'].sum().reset_index()
dfw =df.groupby(['neighbourhood_group'])['price'].mean().reset_index()
review_price=dfv.merge(dfw, how='outer', on='neighbourhood_group') #Merge Both
review_price
# Out:
#   neighbourhood_group  number_of_reviews       price
# 0               Bronx              28371   87.496792
# 1            Brooklyn             486574  124.383207
# 2           Manhattan             454569  196.875814
# 3              Queens             156950   99.517649
# 4       Staten Island              11541  114.812332

# %%
#sort the number of reviews relative to each neighbourhood to find the busiest area
busiest_areas =df.groupby(['neighbourhood_group'])['number_of_reviews'].sum().reset_index().sort_values(by = 'number_of_reviews', ascending =False)
busiest_areas.set_index('neighbourhood_group')
# Out:
#                      number_of_reviews
# neighbourhood_group
# Brooklyn                        486574
# Manhattan                       454569
# Queens                          156950
# Bronx                            28371
# Staten Island                    11541

# %%
#checking total property in each group
total_pre=df.groupby(['neighbourhood_group'])['name'].count().reset_index()
total_pre.rename(columns={'name': 'total_Property'}, inplace=True)
total_pre
# Out:
#   neighbourhood_group  total_Property
# 0               Bronx            1090
# 1            Brooklyn           20098
# 2           Manhattan           21652
# 3              Queens            5666
# 4       Staten Island             373

# %%
# Find the availbility of rooms in the given neighbourhood.
df.groupby(['neighbourhood_group','room_type'])['availability_365'].mean().reset_index().sort_values(by = 'neighbourhood_group', ascending =False)
# Out:
#    neighbourhood_group        room_type  availability_365
# 12       Staten Island  Entire home/apt        178.073864
# 13       Staten Island     Private room        226.361702
# 14       Staten Island      Shared room         64.777778
# 9               Queens  Entire home/apt        132.267176
# 10              Queens     Private room        149.222716
# 11              Queens      Shared room        192.186869
# 6            Manhattan  Entire home/apt        117.140996
# 7            Manhattan     Private room        101.845026
# 8            Manhattan      Shared room        138.572917
# 3             Brooklyn  Entire home/apt         97.205147
# 4             Brooklyn     Private room         99.917983
# 5             Brooklyn      Shared room        178.007264
# 0                Bronx  Entire home/apt        158.000000
# 1                Bronx     Private room        171.331288
# 2                Bronx      Shared room        154.216667

# %%
# Find expensive areas based on its price and room types
# Find the availbility of rooms in the given neighbourhood.
m=df.groupby(['neighbourhood_group','room_type'])['availability_365'].mean().unstack()
m
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     158.000000    171.331288   154.216667
# Brooklyn                   97.205147     99.917983   178.007264
# Manhattan                 117.140996    101.845026   138.572917
# Queens                    132.267176    149.222716   192.186869
# Staten Island             178.073864    226.361702    64.777778

# %%
#checking price list of each type of proprty
dict_ = {}

types_of_rooms = list(df['room_type'].unique())
for rooms in types_of_rooms:
    dict_[rooms] = df[df['room_type'] == rooms].price.sum()/df[df['room_type'] == rooms].price.count()

key, value =  list(dict_.keys()), list(dict_.values())

k = pd.DataFrame({'Rooms': key, 'Average Price': value})

k
# Out:
#              Rooms  Average Price
# 0     Private room      89.780973
# 1  Entire home/apt     211.794246
# 2      Shared room      70.127586

# %%
#unique host in each neighbourhood group
df_va = df.groupby(['neighbourhood_group'])['host_name'].nunique()
df_va
# Out:
# neighbourhood_group
# Bronx             652
# Brooklyn         6075
# Manhattan        5972
# Queens           2424
# Staten Island     220
# Name: host_name, dtype: int64

# %%
dict_1 = {}
dict_2 = {}
df['price_for_a_night'] = df['price'] / df['minimum_nights']

neighbourhood = list(df['neighbourhood'].unique())

for n in neighbourhood:
    if n not in dict_1.keys():
        dict_1[n] = df[df['neighbourhood'] == n].price_for_a_night.mean()


neighbourhood_group = list(df['neighbourhood_group'].unique())

for n in neighbourhood_group:
    if n not in dict_2.keys():
        dict_2[n] = df[df['neighbourhood_group'] == n].price_for_a_night.mean()

# %%
#DataFrame contains competetive price in the unique neighbourhoods group
pd.DataFrame({'Neighbourhood Group' : list(dict_2.keys()), 'Competetive Price' : list(dict_2.values())})
# Out:
#   Neighbourhood Group  Competetive Price
# 0            Brooklyn          57.428778
# 1           Manhattan          86.945981
# 2              Queens          55.307232
# 3       Staten Island          65.941963
# 4               Bronx          50.703610

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
newlist=df['neighbourhood_group'].unique()
y=list(newlist)

# %%
#here checking Top 3 most reviewed premises in each neighbourhood group.
for x in y:
  sub_1=df.loc[df['neighbourhood_group'] == x]
  p_sub1=sub_1.groupby(['neighbourhood_group','neighbourhood','name'])['number_of_reviews'].sum().reset_index().sort_values(by = 'number_of_reviews', ascending =False).head(3)
  m=p_sub1.set_index('name')
  print(m)
# Out:
#                                    neighbourhood_group neighbourhood  \
# name
# Private brownstone studio Brooklyn            Brooklyn    Park Slope
# Loft Suite @ The Box House Hotel              Brooklyn    Greenpoint
# LG Private Room/Family Friendly               Brooklyn      Bushwick
#
#                                     number_of_reviews
# name
# Private brownstone studio Brooklyn                488
# Loft Suite @ The Box House Hotel                  481
# LG Private Room/Family Friendly                   480
#                                neighbourhood_group neighbourhood  \
# name
# Great Bedroom in Manhattan               Manhattan        Harlem
# Beautiful Bedroom in Manhattan           Manhattan        Harlem
# Private Bedroom in Manhattan             Manhattan        Harlem
#
#                                 number_of_reviews
# name
# Great Bedroom in Manhattan                    607
# Beautiful Bedroom in Manhattan                597
# ...

# %%
#Top 3 Host in each neighbourhood group
newlist=df['neighbourhood_group'].unique()
y=list(newlist)
# Applying for loop operation
for x in y:
  sub_1=df.loc[df['neighbourhood_group'] == x]
  p_sub1=sub_1.groupby(['neighbourhood_group'])['host_name'].value_counts().head(3)
  print(p_sub1)
# Out:
# neighbourhood_group  host_name
# Brooklyn             Michael      159
#                      David        142
#                      Sarah        133
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Manhattan            Sonder (NYC)    327
#                      Blueground      230
#                      Michael         212
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Queens               Kazuya       79
#                      David        50
#                      Michael      37
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Staten Island        Maria        9
#                      Amarjit S    8
#                      Marina       8
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Bronx                Vie          13
#                      Armando      10
#                      Carol         9
# Name: count, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Our dataset has 7894 unique properties, and 16 variables (or features). Each of the rows has a property name that has a unique ID and their host, and where that property is located with some other features like room types, reviews, and price. Our first task is to focus on its physical features and its facilities and find out the relationship between top listings prices. We mainly focused on the listing's room type, property type, price, host, location, and reviews. In the given dataset, there are a lot of null values in two columns (last_review and reviews_per_month). So, we drop these columns from the datasets.
# When we checked about hosts, we came to know that we have 11452 unique hosts. And in our entire dataset, about 48895 hosts are registered which means that a particular host is registered in multiple properties. When we further investigated, we found that Sonder (NYC) is the most registered host followed by Blueground, kara, and Kazuya. And we checked the calculated host listing count corresponding to their neighborhood group, and we came to know that the maximum number of the hosts are registered in Manhattan followed by Brooklyn, Queens, Bronx, and Staten Island.
#
# ![Screenshot 2023-01-05 114605.jpg](data:image/jpeg;base64,...)
#
#
# In the above table, we can clearly see the unique host, host listing count, and corresponding neighborhood group.
# when we further inspected a number of review columns we found that the most reviewed place is Brooklyn followed by Manhattan, Queens, and Bronx, and less reviewed place is Staten Island, when we checked the price of these neighborhood groups then we didn't get much information but we found that most reviewed place is quite expensive than other places.
# we inspected further we came to know that most of the properties in Manhattan and followed by Brooklyn, Queens, Bronx, and least in Staten Island (i.e., only 373 properties) and also found that private type of room is most preferable among all and then Entire home/apt and less count of a type of rooms are Shared room that is very less in comparison of other types. In Manhattan, only the Entire home/apt type property is most otherwise the private type property is most popular. So, it's obvious that the Entire home/apt will be costlier than others (i.e., around 211 dollars) followed by private rooms in a price range of about 89 dollars, the cheapest properties are shared rooms (i.e., only 70$). The competitive Price of Manhattan is highest followed by Staten Island and Brooklyn and lowest in the Bronx.
#
# * The number of host listings is highest in Manhattan
# * The percentage of unique host is maximum in Brooklyn(40%) followed by Manhattan(39%)
# * The most reviewed places are Brooklyn and Manhattan
# * Manhattan has more listed properties with Entire homes/apt followed by Brooklyn.
# * Private rooms are most popular among all
# * Manhattan is the costliest place and also the most popular.
# So, after the above analysis, we can conclude that Manhattan and Brooklyn are the most popular neighborhood group.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 : Pie chart of Room types or Proportions of RoomType (Univariate)

# %%
# Here we are defining the plot in percentage
room_types=df['room_type'].value_counts()
#plt.figure(figsize=(10,10))
# Here we are defining the plot in percentage
room_types.plot(kind='pie', autopct='%1.0f%%')
plt.title('Proportion of Room types')
# Out:
# Text(0.5, 1.0, 'Proportion of Room types')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Three types of rooms are Entire Home/Apartment, Private Room, and Shared room. From the above pie chart, we can find the proportion of room types listed in New York. So, we determine the percentage of all room types in the listing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So, in the listed properties, 52% of rooms are Entire Home/Apt, 46% are Private rooms, and only 2% are shared rooms.
# The above chart gives a clear picture of the popularity of all room types. And it indicates that shared rooms are not preferred compared to the remaining room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In the given data, there are three types of rooms available that is private, shared, and entire home/apt. Using the above chart, the host gets proper information about the types of rooms listed in New York. And this information is helpful while taking business decisions. So, the host will get a clear picture that the Private room and Entire room/Apt are more impactful than shared rooms.

# %% [markdown]
# #### Chart - 2 Distribution density plot of Price (Univariate)

# %%
# Chart - 2 visualization code
# Let us analyse the price distribution using distplot
sns.set(rc={"figure.figsize": (15, 6)})
sns.distplot(df["price"], hist=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
# Here we are plotting box plot of Price data.
df['price'].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Distplot or distribution plot depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables i.e., data distribution of a variable against the density distribution.
# Boxplots are a standardized way of displaying the distribution of data based on a five-number summary (i.e., “minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). in the above plot, we can see that most of the data is around the median but there is some data which is far away from the median. Our data have some outliers which are outside of the minimum and maximum values, and we treat them before feeding this to a machine learning model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above density plot, it is visible that there are many of the data lies right to the peak of the data. Because there are some expensive rooms are also present in the dataset. So, the density plot is slightly right skewed.
#
# From the box plot, it is visible that there are lot of outliers in the data. Most of the prices are below 2000 dollars. But some rooms are lot more expensive. So, some prices are above 2000 dollars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here by seeing the above plot the host gets idea of price that is maximum,minimum,median price of each room type of respected premises that are regsitered on Airbnb platform.This data helps the airbnb platform to take decisisons regarding the price of room type.Therefore this plot leads to positive growth in business.

# %% [markdown]
# #### Chart 3- Pi chart of unique host count by its name in each neighbourhood group (Univariate)

# %%
# Chart - 3 visualization code
# Here we are applying group by operation to find unique host in each neighbourhood group.
df_var = df.groupby(['neighbourhood_group'])['host_name'].nunique()
# Here we are defining the pie plot in percentage
df_var.plot(kind='pie', autopct='%1.0f%%')
plt.title('Unique host in each neighbourhood group')
# Out:
# Text(0.5, 1.0, 'Unique host in each neighbourhood group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, we use a pie plot because pie charts are probably better than any other visual for expressing a part-to-whole relationship. It helps to represent the percentage of the unique host in each neighborhood group that is currently active.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this plot, we have founded the group by operation on neighborhood group and calculated counted the unique host that is currently active or booking rooms in each neighborhood group in the given data. In the above plot, we can see that the maximum number of unique hosts are working in the Brooklyn neighborhood group, and the minimum number of unique hosts are working in Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By seeing the above plot host gets an idea of how many numbers of unique hosts are currently active in the particular neighborhood group. The upcoming host can understand which neighborhood group competition will be more. Therefore, it leads to a positive business impact.

# %% [markdown]
# #### Chart - 4 Bar plot of Top 3 active host in each neighbourhood group.

# %%
# Chart - 4 visualization code
newlist=df['neighbourhood_group'].unique()
y=list(newlist)
# Applying for loop operation
for x in y:
  sub_1=df.loc[df['neighbourhood_group'] == x]
  p_sub1=sub_1.groupby(['neighbourhood_group'])['host_name'].value_counts().head(3)
  print(p_sub1)
  plt.figure(figsize=(5,3))
  p_sub1.plot(kind='bar')
  plt.title('Top 3 host in '+str(x))
  plt.xlabel("Hosts")
  plt.ylabel("Counting")
# Out:
# neighbourhood_group  host_name
# Brooklyn             Michael      159
#                      David        142
#                      Sarah        133
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Manhattan            Sonder (NYC)    327
#                      Blueground      230
#                      Michael         212
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Queens               Kazuya       79
#                      David        50
#                      Michael      37
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Staten Island        Maria        9
#                      Amarjit S    8
#                      Marina       8
# Name: count, dtype: int64
# neighbourhood_group  host_name
# Bronx                Vie          13
#                      Armando      10
#                      Carol         9
# Name: count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, we have used a barplot because bar charts are good for comparing each element. We have compared different hosts' names based on hostname count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here, in the above plot, we have found the top 3 active hosts in each neighborhood group based on the unique hostname.
#
# In Brooklyn:
#
# 1. Michael
# 2. David
# 3. Sarah
#
# In Manhattan
# 1. Sonder (NYC)
# 2. Blueground
# 3. Michael
#
# In Queens
# 1. Kazuya
# 2. David
# 3. Michael
#
# In Staten Island
# 1. Maria
# 2. Amarjit
# 3. Marina
#
# In Bronx
# 1. Vie
# 2. Armando
# 3. Carol

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the above insights are helpful in positive growth because the host will be able to know its best competitors in each neighborhood group and can follow their pattern to achieve positive business growth.

# %% [markdown]
# #### Chart - 5 Finding the top 5  host based on calculated_host_listings_count (Bivariate)

# %%
# Chart - 5 visualization code
# Here we are applying group by operation
df1=df.groupby(['host_name'])['calculated_host_listings_count'].max().reset_index().sort_values(by='calculated_host_listings_count', ascending=False).head()
plt.rcParams['figure.figsize'] = (10, 5)

plt.bar(df1['host_name'], df1['calculated_host_listings_count'], color ='green',
        width = 0.5)
plt.title("Top 5 Host based on host listing count")
plt.xlabel("Host Name")
plt.ylabel("Host Listing Counts")
# Out:
# Text(0, 0.5, 'Host Listing Counts')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, we have used a bar plot because a barplot is one of the most efficient ways of representing data. It is used to summarize large data in visual form, considering a numerical and a categorical feature.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here, Sonder (NYC), Blueground, Kara, Kazuya, and Sonder are the top 5 hosts based on the host listing count.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here by seeing the above plot the host will come to know which host has maximum listing in the Newyork City.Therefore it leads positive business growth.

# %% [markdown]
# #### Chart - 6 Numbers of Unique room type in each neighbourhood group.(Bivariate)

# %%
# Chart - 6 visualization code
# Here we are applying group by operation to count unique room type in each neighbourhood group.
df_plot=df.groupby(['neighbourhood_group'])['room_type'].value_counts().unstack()
z=df_plot.reset_index()
# plot a Stacked Bar Chart using matplotlib
z.plot( x = 'neighbourhood_group',  kind = 'barh',  stacked = True,
       title = 'Percentage Stacked Bar Graph',  mark_right = True)
# Out:
# <Axes: title={'center': 'Percentage Stacked Bar Graph'}, ylabel='neighbourhood_group'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The above plot represents a stacked barplot because a stacked barplot is used to break down and compare parts of a whole. Each bar in the chart represents a whole, and segments in the bar represent different parts or categories of that whole. Different colors are used to illustrate the different categories in the bar. Here, we have compared the number of each room type in each neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above stacked barplot we can conclude that:
#
# 1. **In Manhattan**
#
# The number of Entire home/Apt is maximum compared to the private and shared rooms.
# 2. **In Staten Island**
#
# The number of Private room is maximum compared to the Entire home/Apt and shared rooms.
#
# 3. **In Queens**
#
# The number of Private room is maximum compared to the Entire home/Apt and shared rooms.
#
# 4. **In Brooklyn**
#
# The number of Private room is maximum compared to the Entire home/Apt and shared rooms.
#
#
# 5. **In Bronx**
#
# The number of Private room is maximum compared to the Entire home/Apt and shared rooms.
#
#
#  **Here we can also see that:**
#
# *   The number of private rooms in Brooklyn compared to other neighborhood groups is the highest.
# *   The number of Entire home/Apt in Manhattan compared to other neighborhood groups is the highest.
#
# *  The number of shared room in Manhattan compared to other neighborhood groups is the highest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plot, the host gets an idea about the number of room types in each neighborhood group. So, if a host wants to add new premises to Airbnb, then by seeing the above plot, he can add or decrease the types of rooms in his premises. Therefore, it leads to positive business growth.

# %% [markdown]
# #### Chart - 7 Revenue generated from different neighbourhood group (Bivariate)

# %%
# Chart - 7 visualization code
import matplotlib.pyplot as plt

# Setting labels for items in Chart
neigh_group = ['Bronx', 'Brooklyn', 'Manhattan',
            'Queens', 'Staten Island']

# Setting size in Chart based on
# given values
income = [ 95459, 2500600, 4264527,563867,  42825]

# colors
colors = ['#FF0004', '#737CA1', '#FFFF00',
          '#ADFF2F', '#FFA500']
# explosion
explode = (0.5, 0.05, 0.05, 0.5,0.5)

# Pie Chart
plt.pie(income, labels=neigh_group,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)

# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()

# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)

# Adding Title of chart
plt.title('Revenue generated from different neighbourhood group')

# Displaying Chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, we have used the donut plot which is the modified version of the pie plot. It is more concerned with an area of arcs to represent the information in the most effective manner instead of a Pie chart. It represents the percentage of revenue generated from the different neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By seeing the above plot, we can see that portion of revenue generated from each neighbourhood group:
# 1. Manhattan generates 57.1 % of total revenue.
# 2. Brooklyn generates 33.5 % of total revenue.
# 3. Queens generates 7.6 % of total revenue.
# 4. Bronx generates 1.3 % of total revenue.
# 5. Staten Island generates 0.6 % of total revenue.
#
# So, Manhattan and Brooklyn are the two neighborhood_group that are contributing a lot to the total revenue generated from Airbnb listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plot, the host gets an idea from which part of the neighborhood group the revenue is maximum or minimum. This plot helps the host to takes important decisions regarding increasing his revenue. Here, a host can see that if he belongs to the Manhattan neighborhood group, then there are more chances of increasing revenue. Therefore, this insight leads to positive business growth.

# %% [markdown]
# #### Chart - 8  Average money spend by people on each room types.(Bivariate)

# %%
# Chart - 8 visualization code
dict_ = {}  # creating empty dictionary
types_of_rooms = list(df['room_type'].unique())
for rooms in types_of_rooms:
    dict_[rooms] = round(df[df['room_type'] == rooms].price.sum()/df[df['room_type'] == rooms].price.count())
key, value =  list(dict_.keys()), list(dict_.values())
k = pd.DataFrame({'Rooms': key, 'Average Price': value})
#create bar plot to visualize sales by product
ax =plt.bar(x=k['Rooms'],height=k['Average Price'],fc='lightblue',ec='black')
plt.xlabel("Types of available room", fontsize = 14)
plt.ylabel("Average Spending on each room", fontsize = 14)
plt.title("Average Money spent by peoples in the diferrent types of rooms", fontsize = 20)
# Adding labels to bar plot.
for i in range(len(k['Rooms'])):
  plt.text(i,k['Average Price'][i],k['Average Price'][i],ha='center',va='bottom')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, we have used a bar graph because a bar graph is a very helpful and easy way of comparing different features. Here, we have compared average money spend by people on each room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above plot shows the average price for different room types in each neighbourhood group.
# 1.  The average price for Private Room is around 90 dollar.
# 2.  The average price for Entire home/apt is around 212 dollar.
# 3.  The average price for Shared Room is around 70 dollar.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plot or insight, an upcoming host gets an idea about the average price of each room type. He can decide the price of each room type accordingly. So, he can change the price of different rooms to increase his bookings. Therefore, this insight leads to positive business growth.

# %% [markdown]
# #### Chart - 9 Scatter plot of number of reviews and price considering the room types (mutivariate)

# %%
# Chart - 9 visualization code
# scatter plot between the number of reviews and price considering room types
sns.scatterplot(x='price', y='number_of_reviews', hue='room_type', data=df )
plt.xlabel("Price of Rooms")
plt.ylabel("Number of Reviews")
plt.title("Number of Reviews v/s Cost Price)")
# Out:
# Text(0.5, 1.0, 'Number of Reviews v/s Cost Price)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, we choose the scatterplot between the price and the number of reviews. This indicates the clear relationship between the price and the number of reviews. And this is a multivariate analysis because we are considering three features of the dataset to draw the above plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows the room types whose price is low and is getting comparatively more reviews. So, the rooms are getting booked whose price is low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight can be used to create a positive business impact because it is clearly visible that if the price is low, it will be booked more often.
# If we decide the price according to the above insight to get more clients, this will lead to positive business growth.

# %% [markdown]
# #### Chart -10 Scatter Plot between the longitude and latitude considering the neighbourhood_group (Mutivariate)

# %%
# Chart -10 visualization code
#here we have used scatter plot so that we can easily draw the map of each neighbourhood group
sns.set(rc={"figure.figsize": (10, 8)})
ax= sns.scatterplot(data=df, x="longitude", y="latitude",hue='neighbourhood_group',palette='bright')
ax.set_title('Location Co-ordinates of each neighbourhood group')
# Out:
# Text(0.5, 1.0, 'Location Co-ordinates of each neighbourhood group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose the above chart to find how densely the locations of rooms are in each neighbourhood_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart, it is visible that in Manhattan, the premises are densely populated. In Brooklyn and Manhattan, rooms or hotels are present at a very minimal distance, whereas the rooms are not closely located in Staten Island and the Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This gained insight will help for upcoming hotels in each neighbourhood_group. This also indicates that there may be tourist attractions in Manhattan and Brooklyn because hotels are closely located. So, this will create a positive business impact.

# %% [markdown]
# #### Chart - 11 Scatter plot denoting the distribution of locations of rooms in each neighbourhood (multivariate)

# %%
# Chart - 11 visualization code
#Let's see the distribution of room_types in each neighbourhood group

for col in list(df.neighbourhood_group.unique()):
  data=df.loc[df['neighbourhood_group'] ==col]
  plt.subplots(1,1)
  sns.set(rc={"figure.figsize": (10, 8)})
  ax= sns.scatterplot(data=data, x="longitude", y="latitude",hue='room_type')
  ax.set_title(f'Location Co-ordinates of {col} with its room types')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart gives us the distribution of room types concerning their location (considering their longitude and latitude).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In Brooklyn, we can see **Private Room** and **Entire home/Apartment** are homogeneously distributed across all locations.
#
# In Manhattan, we can see **Entire home/Apartment** is densely located in the west compared to **Private Room**.
#
#
# In Queens, Staten Island, and the Bronx, we can see **Private Room** and **Entire home/Apartment** are homogeneously distributed across all locations. And shared rooms are only 2% of the total listing so, these types of rooms are very in each neighbourhood_group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight is useful for upcoming rooms in these neighbourhood_group. So, new types of a room should be opened considering the locations of existing hotels or rooms.
# So, this information will lead to a positive business impact.

# %% [markdown]
# #### Chart - 12  Bar plot of Availability of room types (Multivariate)

# %%
# Chart - 12 visualization code
# Find the availbility of rooms in the given neighbourhood.
m=df.groupby(['neighbourhood_group','room_type'])['availability_365'].mean().unstack()
m.plot(kind='bar')
plt.title("Availability of rooms in each neighbourhood group.")
plt.xlabel("Neighbourhood group")
plt.ylabel(" Number of Days availability")
# Out:
# Text(0, 0.5, ' Number of Days availability')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we have used bar plots because bar plots are very helpful in comparison of various features of the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this, we have used group by operation and taken the mean of availability_365 data to find the availability of room type in each
# neighborhood group. By seeing the above plot, we can see the chances of getting different room types in each neighborhood group.
# 1. In Staten Island chances of getting a Private room is high.
# 2. In Queens chances of getting Share room is high.
# 3. In Manhattan chances of getting Share room is high.
# 4. In Brooklyn chances of getting a shared room is high.
# 5. In the Bronx chances of getting a Private room is high

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above plot, the host gets an idea about the availability of rooms in the particular neighborhood_group. The room price can be decided high or low. That is, if the availability of a particular room type is low, then its price can be high. And if the availability of rooms is high, then their price can be low. So, the rooms can easily be occupied. Therefore these insights lead to positive growth in business.

# %% [markdown]
# #### Chart - 13 # On an average for how many nights people stayed in each room_types.(Multivariate)

# %%
# Chart - 13 visualization code
# Here we are applying group by operation on room types on the basis of mean of minimum nights.
min_night=df.groupby(['neighbourhood_group','room_type'])['minimum_nights'].mean().unstack()
plt.figure(figsize = (5, 3))


round(min_night).plot(kind='bar')

plt.title('Average minimum Stays in different room types listed on Airbnb ')
plt.xlabel('Neighbourhood group')
plt.ylabel('Average Minimum nights')
# Out:
# Text(0, 0.5, 'Average Minimum nights')

# %% [markdown]
# Here we can see that people preferred to stay in an Entire home/apartment for around 8 days followed by a shared room for around 6 days and a Private room for 5 days.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we have used a bar plot. From a bar plot, we can easily compare the categorical data. Here we are comparing average minimum night stays oy each room type in a different neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here by seeing the above plot we can see that Average minimum Stays in different room types listed on Airbnb:
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here average minimum stays is an average of how many nights people stay in different room types of the different neighborhood groups. From this plot, the host gets an idea of an average of how many nights people stay so based on the average stay availability of rooms can be predicted. It also helps to understand people's behavior towards different types of rooms in different neighborhood groups. Therefore this insight leads to positive business growth.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is already defined
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Create the correlation matrix
corr_df = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))  # Optional: Adjust the size of the heatmap
sns.heatmap(corr_df, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmap is plotted to find the correlation between different features. This helps in feature engineering and removing multicollinearity between the features. In the heatmap, a feature's correlation is depicted concerning each numeric feature present in the dataset. Here, -1 shows a highly negative correlation whereas 1 shows a highly positive correlation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the above heatmap, it is depicted that price and price_for_a_night are highly correlated. And this collinearity should be removed or minimized using feature engineering because these two columns are highly correlated.
# From the heatmap, it is clear that all features are not correlated or very minute correlations between the variables.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

pair_df=df.drop(['longitude','latitude'], axis=1)
sns.pairplot(pair_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot shows the scatter plot of a variable concerning each variable present in the dataset. The show we get a clear picture of the relation between a variable corresponding to the remaining variables. So, the pair plot best represents the relationship between the numeric variables because the pair plot is plotted considering the numerical features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Hence, the pair plot contains scatterplots, and the scatterplot reflects the relationship between two variables. So, from the above pair plot, we can say that there is no highly positive or negative correlation between any two features in the dataset.
# Apart from positive or negative correlations, we can see how one variable is changing corresponding to another.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Solutions to make the host listings attractive.**
# * Periodically look at the customer reviews so that based on the review host can upgrade the rooms.
# * The host must follow the business pattern of top active hosts.
# * The host must focus on the Private and Entire home/Apt because its demand is high.
# * The Premises should be in the Average price range of each room type in the respected neighborhood group.
# * By keeping eye on the nearest host premises whether they giving any offers or not to visitors to increase their bookings.
# * By keeping an eye on the location of premises that in which location demand for which room types is high.
# * The new host must open his premises in the Manhattan neighborhood group because in manhattan the bookings are and most of the revenue of Airbnb is generated from Manhattan as compared to other neighborhood groups.
# * It can be the best opportunity for the host to add his premises to the Staten Island neighborhood group because here premises are low in number and there will be less competition between the hosts.
#
# * They have to maintain their rating for this, along with the price they will also have to provide great service to the customer
#
# * Stay competitive and updated

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Busiest place is Manhattan followed by Brooklyn.
#
# *  Based on the host listing count the maximum number of hosts are registered in Manhattan.
#
# * The Maximum number of unique hosts (that are currently booked in the given dataset) in Brooklyn.
#
# *   Visitors prefer to stay in private type rooms or Entire Home/Apt but among these visitors are liking the Entire Home/Ap the most.
#
# *  The room types whose price is low, and are getting comparatively more reviews. So, the rooms are getting booked whose price is low.
#
# *   The most expensive premises is Entire Home/Ap type, yet people prefer to stay in it, the cheapest is the shared room type, yet people do not like to live in it.
#
# *  Based on the reviews Premises in Manhattan got the most Positive Reviews followed by Brooklyn.
#
# * Based on price, the most expensive place is Manhattan followed by Brooklyn and the cheapest is the Bronx yet people prefer to live in Manhattan and Brooklyn.
#
# *  The maximum Revenue generated from Manhattan followed by Brooklyn.
#
# *  On average spending of people on the Home/Apt type is 212 dollar followed by Private type room is 90 dollar and Shared room 70 dollar.
#
# *  From the above analysis we found that Manhattan and Brooklyn is the most attractive place for tourists and also are the best place from a business perspective for the Hosts.

# %% [markdown]
# We have reached almost the end of this project. In this project, we analyzed almost every column or variable of the data set. In this, we have done data wrangling that is checking or removing null values and checking for unique values and names.
# We have analyzed almost every possible problem statement related to the dataset so that the client can easily understand the data set.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
